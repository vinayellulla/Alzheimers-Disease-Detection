# %% [markdown]
# # Image Preprocessing

# %%
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, WeightedRandomSampler
from PIL import Image
import numpy as np
import random
import cv2
import matplotlib.pyplot as plt
import pickle

random.seed(0)
torch.manual_seed(0)
np.random.seed(0)
torchvision.disable_beta_transforms_warning()

# %% [markdown]
# ## CustomDataset to import dataset

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os

class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = os.listdir(root_dir)[1:]
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}
        self.images = self._get_images()
        self.class_count = self._get_class_count()
        self.images_splited_each_class = self._split_img_each_class()

    def _get_images(self):
        images = []
        for cls in self.classes:
            class_path = os.path.join(self.root_dir, cls)
            class_idx = self.class_to_idx[cls]
            for img_name in os.listdir(class_path):
                img_path = os.path.join(class_path, img_name)
                images.append((img_path, class_idx))
        return images
    
    def _get_class_count(self):
        class_count = {}
        for cls_name in self.class_to_idx.values():
            class_count[cls_name] = 0
        for key,value in self.images:
           class_count[value] += 1 
        return class_count
    
    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path, label = self.images[idx]
        img = Image.open(img_path).convert('RGB')

        if self.transform:
            img = self.transform(img)
        return img, label
    
    def _get_labels(self):
        return [i[1] for i in self.images]
    
    def _split_img_each_class(self):
        data_class_split = {}
        for i in self.class_to_idx.values():
            data_class_split[i] = []
        for i in self.class_to_idx.values():
            for j in range(len(self.images)):
                if self.images[j][-1] == i:
                    data_class_split[i].append(self.images[j])
        return data_class_split

# %%
sample_data = CustomDataset(root_dir='Dataset')

# %%
import matplotlib.image as mpimg
import copy

sample_data_dict = copy.deepcopy(sample_data.images_splited_each_class)

# create 4x1 subplots
fig, axs = plt.subplots(nrows=4, ncols=1, constrained_layout=True, figsize=(10, 10))
fig.suptitle('Sample 20 data (5 images for each class)')

# clear subplots
for ax in axs:
    ax.remove()

# add subfigure per subplot
gridspec = axs[0].get_subplotspec().get_gridspec()
subfigs = [fig.add_subfigure(gs) for gs in gridspec]

for row, subfig in enumerate(zip(subfigs,sample_data.classes)):
    subfig[0].suptitle(subfig[-1])

    # create 1x5 subplots per subfig
    axs = subfig[0].subplots(nrows=1, ncols=5)

    for class_label, images in sample_data_dict.items():
        for i in range(5):
            img = mpimg.imread(images[i][0])
            axs[i].imshow(img,cmap='gray')
            axs[i].axis('off')
        break
 
    del sample_data_dict[class_label]

plt.show()

# %% [markdown]
# ## Augmentation

# %% [markdown]
# ### AddGaussianNoise

# %%
class AddGaussianNoise(object):
    def __init__(self, mean=0.0, std=1.0, probability=0.5):
        self.std = std
        self.mean = mean
        self.probability = probability
        
    def __call__(self, tensor):
        if random.random() < self.probability:
            return tensor + (torch.randn(tensor.size()) * self.std) + self.mean
        else:
            return tensor
    
    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

# %% [markdown]
# ### Contrast-limited Adaptive Histogram Equalization (CLAHE)

# %%
# Reading the image from the present directory
image = cv2.imread('Dataset/Mild_Demented/mild_2.jpg')
# Resizing the image for compatibility

# The initial processing of the image
# image = cv2.medianBlur(image, 3)
image_bw = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
# The declaration of CLAHE
# clipLimit -> Threshold for contrast limiting
clahe = cv2.createCLAHE(clipLimit=3,tileGridSize=(1,1))
final_img = clahe.apply(image_bw) + 200
 
# Showing the two images
plt.imshow(cv2.cvtColor(image_bw, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

plt.imshow(cv2.cvtColor(final_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import cv2

class AddCLAHE():
    def __init__(self, clipLimit=3, tileGridSize=(1, 1), threshold=200) -> None:
        self.clipLimit = clipLimit
        self.tileGridSize = tileGridSize
        self.threshold = threshold

    def __call__(self, tensor):
        tensor = tensor.numpy() * 255 
        tensor = tensor.astype('uint8')[0]

        clahe = cv2.createCLAHE(clipLimit=self.clipLimit, tileGridSize=self.tileGridSize)
        transformed_tensor = clahe.apply(tensor)
        transformed_tensor = torch.from_numpy(transformed_tensor).float() + self.threshold
        transformed_tensor = transformed_tensor / 255
        transformed_tensor = transformed_tensor.unsqueeze(0)

        return transformed_tensor

    def __repr__(self):
        return self.__class__.__name__ + '(clipLimit={}, tileGridSize={}, threshold={})'.format(
            self.clipLimit, self.tileGridSize, self.threshold
        )

# %% [markdown]
# ### Split white and gray matter

# %%
class split_white_and_gray():
    def __init__(self,threshold=120) -> None:
        self.threshold = threshold

    def __call__(self,tensor):
        tensor = (tensor*255).to(torch.int64)

        # Apply thresholding
        gray_matter = torch.where(tensor >= self.threshold,tensor,0)
        gray_matter = (gray_matter/255).to(torch.float64)
        white_matter = torch.where(tensor < self.threshold,tensor,0)
        white_matter = (white_matter/255).to(torch.float64)
        tensor = (tensor/255).to(torch.float64)

        return torch.cat((gray_matter, white_matter,tensor), dim=0)

# %% [markdown]
# # Prepare Dataset

# %% [markdown]
# ## Data transforms

# %%
transform = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    #split_white_and_gray(120),
    #AddCLAHE(),
    #AddGaussianNoise(0,0.05), 
])

# %%
Dataset = CustomDataset(root_dir='Dataset', transform=transform)

# %%
plt.imshow(transforms.ToPILImage()(Dataset[0][0][0]),cmap='gray')
plt.show()

# %%
plt.imshow(transforms.ToPILImage()(Dataset[0][0][1]),cmap='gray')
plt.show()

# %% [markdown]
# ## Split dataset

# %%
from torch.utils.data import random_split

# Assuming you have a dataset named 'dataset' and it contains your data
dataset_size = len(Dataset)
train_size = int(0.7 * dataset_size)  # 70% for training
val_size = int(0.15 * dataset_size)  # 15% for validation
test_size = dataset_size - train_size - val_size  # Remaining 15% for testing

train_dataset, val_test_dataset = random_split(Dataset, [train_size, val_size + test_size])
val_dataset, test_dataset = random_split(val_test_dataset, [val_size, test_size])

# %% [markdown]
# ## Over sampling method

# %%
def OverSample(Dataset):
    data = list(Dataset)
    class_count = {0:0, 1:0, 2:0, 3:0}
    for _, class_name in data:
        class_count[class_name] += 1

    # Calculate class weights for oversampling
    class_counts = list(class_count.values())
    class_weights = 1.0 / torch.tensor(class_counts, dtype=torch.float)

    # Assign weights to each sample based on its class
    
    weights = [class_weights[label] for _, label in data]

    # Create a WeightedRandomSampler to oversample minority classes
    sampler = WeightedRandomSampler(weights, 10000, replacement=True)

    return sampler

# %% [markdown]
# ## Apply DataLoader

# %%
batch_size=64

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, sampler=OverSample(train_dataset))
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, sampler=OverSample(val_dataset))
test_dataloader = DataLoader(test_dataset, batch_size=batch_size,)

# %%
class_counts = {label: 0 for label in range(len(Dataset.classes))}

# Iterate through the DataLoader
for _, labels in train_dataloader:
    for label in labels:
        class_counts[label.item()] += 1

# Print the counts
for label, count in class_counts.items():
    print(f"Class {label}: {count} items")
# Out:
# Class 0: 2482 items
# Class 1: 2580 items
# Class 2: 2425 items
# Class 3: 2513 items

# %%
# Create a figure with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))  # Adjust the figsize as needed

# Add the first subplot
ax1.bar(Dataset.classes, Dataset.class_count.values())
ax1.set_xticks(range(len(Dataset.classes)))
ax1.set_xticklabels(Dataset.classes, rotation=45)
ax1.set_ylim(top=6000)
ax1.set_title("Before Over sampling")

# Add the second subplot
ax2.bar(Dataset.classes, class_counts.values())
ax2.set_xticks(range(len(Dataset.classes)))
ax2.set_xticklabels(Dataset.classes, rotation=45)
ax2.set_ylim(top=6000)
ax2.set_title("After Over sampling")

plt.show()

# %% [markdown]
# ## visualization of each class

# %%
images, labels = next(iter(train_dataloader))

img_index = []
for label in labels.unique():
    img_index.append(list(labels).index(label))

image_each_classes = []
for idx in img_index:
    image_each_classes.append(images[idx])

# Plot one image from each class
fig, axs = plt.subplots(1, len(Dataset.classes), figsize=(15, 3))
fig.suptitle("White matter from Each Class", fontsize=16)

for class_num, i in enumerate(zip(Dataset.classes,image_each_classes)):
    axs[class_num].imshow(transforms.ToPILImage()(i[-1][0]),cmap='gray')
    axs[class_num].set_title(f"Class {i[0]}")
    axs[class_num].axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot one image from each class
fig, axs = plt.subplots(1, len(Dataset.classes), figsize=(15, 3))
fig.suptitle("Gray matter from Each Class", fontsize=16)

for class_num, i in enumerate(zip(Dataset.classes,image_each_classes)):
    axs[class_num].imshow(transforms.ToPILImage()(i[-1][1]),cmap='gray')
    axs[class_num].set_title(f"Class {i[0]}")
    axs[class_num].axis('off')

plt.tight_layout()
plt.show()

# %%
# Plot one image from each class
fig, axs = plt.subplots(1, len(Dataset.classes), figsize=(15, 3))
fig.suptitle("Original image from Each Class", fontsize=16)

for class_num, i in enumerate(zip(Dataset.classes,image_each_classes)):
    axs[class_num].imshow(transforms.ToPILImage()(i[-1][2]),cmap='gray')
    axs[class_num].set_title(f"Class {i[0]}")
    axs[class_num].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## save data variable

# %%
# pickle.dump(Dataset, open('Dataset.pkl', 'wb'))
# pickle.dump(train_dataloader, open('train_dataloader.pkl', 'wb'))
# pickle.dump(val_dataloader, open('val_dataloader.pkl', 'wb'))
# pickle.dump(test_dataloader, open('test_dataloader.pkl', 'wb'))

# %% [markdown]
# # Model Training

# %% [markdown]
# class names : https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json,
# https://github.com/anishathalye/imagenet-simple-labels/blob/master/imagenet-simple-labels.json

# %%
import requests

# Fetch the ImageNet class labels
LABELS_URL = 'https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json'
response = requests.get(LABELS_URL)
labels = response.json()

labels[:10]
# Out:
# ['tench',
#  'goldfish',
#  'great white shark',
#  'tiger shark',
#  'hammerhead shark',
#  'electric ray',
#  'stingray',
#  'cock',
#  'hen',
#  'ostrich']

# %% [markdown]
# ## Train Function

# %%
from torch.optim import lr_scheduler
import tqdm.notebook as tq
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from sklearn.metrics import accuracy_score

def train(model:models, traindata:DataLoader, valdata:DataLoader, device = torch.device("mps" if torch.backends.mps.is_available() else "cpu"),num_epochs=50) -> tuple:
    # training
    # Loop for training
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

    num_epochs = num_epochs
    train_loss_history = []
    train_accuracy_history = []
    validation_loss_history = []
    validation_accuracy_history = []

    for epoch in tq.tqdm(range(num_epochs), desc="Epoch num", position=0, leave=True):
        # Train set
        running_loss = 0.0
        all_labels = []
        all_predictions = []

        # Val set
        val_running_loss = 0.0
        val_all_labels = []
        val_all_predictions = []

        # Use tqdm for progress visualization
        for i, data in enumerate(zip(traindata, valdata)):
            model.train()#change mode to training

            train_set, val_set = data
            inputs, labels = train_set

            optimizer.zero_grad()

            # Move inputs and labels to device
            inputs, labels = inputs.to(torch.float32).to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            

            # Track predictions for accuracy calculation
            _, predictions = torch.max(outputs, 1)
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predictions.cpu().numpy())

            # Accumulate the loss
            running_loss += loss.item()
    #################################################################################################        
            # loss and acc on validation set
            model.eval() #change mode to evaluation
            with torch.no_grad():
                val_inputs, val_labels = val_set
                val_inputs, val_labels = val_inputs.to(torch.float32).to(device), val_labels.to(device)

                val_outputs = model(val_inputs)
                val_loss = criterion(val_outputs, val_labels)

                _, val_predictions = torch.max(val_outputs, 1)
                val_all_labels.extend(val_labels.cpu().numpy())
                val_all_predictions.extend(val_predictions.cpu().numpy())

                val_running_loss += val_loss.item()
    #################################################################################################
        scheduler.step()

        # Calculate accuracy on training set
        accuracy = accuracy_score(all_labels, all_predictions)
        average_train_loss = running_loss / len(train_dataloader)
        train_loss_history.append(average_train_loss)
        train_accuracy_history.append(accuracy)

        # Calculate accuracy on validation set
        val_accuracy = accuracy_score(val_all_labels, val_all_predictions)
        average_validation_loss = val_running_loss / len(val_dataloader)
        validation_loss_history.append(average_validation_loss)
        validation_accuracy_history.append(val_accuracy)
        
        # Print statistics for the epoch
        print("-------------------------------------------------------------------")
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print(f"Training Loss   : {average_train_loss:.3f}  |  Training Accuracy   : {accuracy:.3f}")
        print(f"Validation Loss : {average_validation_loss:.3f}  |  Validation Accuracy : {val_accuracy:.3f}")
        print("-------------------------------------------------------------------")
        print()
    
    return train_loss_history, train_accuracy_history, validation_loss_history, validation_accuracy_history

# %% [markdown]
# ## ResNet18

# %% [markdown]
# ### Transfer

# %%
import torch.nn as nn
import torchvision.models as models
import collections
import torch.optim as optim
from sklearn.metrics import accuracy_score

class Resnet18_backbone(nn.Module):
    def __init__(self):
        super(Resnet18_backbone, self).__init__()
        self.numclass =  4
        self.resnet18 = models.resnet18()
        self.resnet18_removelast = nn.Sequential(*list(self.resnet18.children())[:-1])
        self.classification_head = nn.Sequential(
                                                    nn.Linear(512, 256),  # Linear layer
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(256, 128),
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(128, self.numclass),
                                                    nn.Softmax(dim=1),
                                                )
        self.resnet18_backbone = nn.Sequential(
                                                    collections.OrderedDict(
                                                        [
                                                            ("resnet18", self.resnet18_removelast),
                                                            ("Flatten", nn.Flatten()),  # Flatten the output
                                                            ("Head", self.classification_head),
                                                        ]
                                                    )
                                                )
        
    def forward(self, x):
        return self.resnet18_backbone(x)

# %%
# Move the model to device
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
resnet18 = Resnet18_backbone().to(torch.float32).to(device)

# %% [markdown]
# ### Draw graph

# %%
# from torchviz import make_dot

# # Generate a visual representation of the model's computational graph
# x = torch.randn(1, 3, 150, 150)  # Example input
# y = resnet18_backbone(x)
# dot = make_dot(y, params=dict(resnet18.named_parameters()))

# # Save the generated graph as an image
# dot.render("your_model_graph")

# %% [markdown]
# ### training

# %%
train_loss, train_acc, val_loss, val_acc = train(resnet18,train_dataloader,val_dataloader)
# Out:
# Epoch num:   0%|          | 0/50 [00:00<?, ?it/s]
# -------------------------------------------------------------------
# Epoch 1/50
# Training Loss   : 1.086  |  Training Accuracy   : 0.644
# Validation Loss : 1.381  |  Validation Accuracy : 0.350
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 2/50
# Training Loss   : 1.002  |  Training Accuracy   : 0.737
# Validation Loss : 1.193  |  Validation Accuracy : 0.541
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 3/50
# Training Loss   : 0.972  |  Training Accuracy   : 0.767
# Validation Loss : 1.179  |  Validation Accuracy : 0.558
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 4/50
# Training Loss   : 0.931  |  Training Accuracy   : 0.810
# Validation Loss : 1.113  |  Validation Accuracy : 0.627
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 5/50
# Training Loss   : 0.925  |  Training Accuracy   : 0.816
# Validation Loss : 1.075  |  Validation Accuracy : 0.662
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 6/50
# Training Loss   : 0.870  |  Training Accuracy   : 0.872
# Validation Loss : 0.917  |  Validation Accuracy : 0.823
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 7/50
# Training Loss   : 0.835  |  Training Accuracy   : 0.909
# Validation Loss : 0.864  |  Validation Accuracy : 0.877
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 8/50
# Training Loss   : 0.818  |  Training Accuracy   : 0.924
# Validation Loss : 0.865  |  Validation Accuracy : 0.875
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 9/50
# Training Loss   : 0.813  |  Training Accuracy   : 0.930
# Validation Loss : 0.848  |  Validation Accuracy : 0.895
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 10/50
# Training Loss   : 0.798  |  Training Accuracy   : 0.945
# Validation Loss : 0.846  |  Validation Accuracy : 0.896
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 11/50
# Training Loss   : 0.798  |  Training Accuracy   : 0.947
# Validation Loss : 0.836  |  Validation Accuracy : 0.908
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 12/50
# Training Loss   : 0.790  |  Training Accuracy   : 0.954
# Validation Loss : 0.836  |  Validation Accuracy : 0.907
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 13/50
# Training Loss   : 0.788  |  Training Accuracy   : 0.957
# Validation Loss : 0.833  |  Validation Accuracy : 0.909
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 14/50
# Training Loss   : 0.786  |  Training Accuracy   : 0.958
# Validation Loss : 0.830  |  Validation Accuracy : 0.911
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 15/50
# Training Loss   : 0.786  |  Training Accuracy   : 0.958
# Validation Loss : 0.829  |  Validation Accuracy : 0.915
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 16/50
# Training Loss   : 0.789  |  Training Accuracy   : 0.956
# Validation Loss : 0.822  |  Validation Accuracy : 0.922
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 17/50
# Training Loss   : 0.784  |  Training Accuracy   : 0.960
# Validation Loss : 0.827  |  Validation Accuracy : 0.916
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 42/50
# Training Loss   : 0.779  |  Training Accuracy   : 0.966
# Validation Loss : 0.825  |  Validation Accuracy : 0.918
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 43/50
# Training Loss   : 0.788  |  Training Accuracy   : 0.957
# Validation Loss : 0.827  |  Validation Accuracy : 0.916
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 44/50
# Training Loss   : 0.785  |  Training Accuracy   : 0.959
# Validation Loss : 0.829  |  Validation Accuracy : 0.914
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 45/50
# Training Loss   : 0.785  |  Training Accuracy   : 0.959
# Validation Loss : 0.822  |  Validation Accuracy : 0.922
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 46/50
# Training Loss   : 0.781  |  Training Accuracy   : 0.963
# Validation Loss : 0.827  |  Validation Accuracy : 0.917
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 47/50
# Training Loss   : 0.785  |  Training Accuracy   : 0.959
# Validation Loss : 0.825  |  Validation Accuracy : 0.918
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 48/50
# Training Loss   : 0.781  |  Training Accuracy   : 0.963
# Validation Loss : 0.831  |  Validation Accuracy : 0.911
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 49/50
# Training Loss   : 0.785  |  Training Accuracy   : 0.959
# Validation Loss : 0.833  |  Validation Accuracy : 0.910
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 50/50
# Training Loss   : 0.783  |  Training Accuracy   : 0.961
# Validation Loss : 0.822  |  Validation Accuracy : 0.922
# -------------------------------------------------------------------

# %% [markdown]
# ### Loss and Acc on Training

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the seaborn style
sns.set(style="whitegrid")

# Create two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the Loss
sns.lineplot(x=range(1, len(train_loss) + 1), y=train_loss, label='Training Loss', marker='o', ax=axes[0])
sns.lineplot(x=range(1, len(val_loss) + 1), y=val_loss, label='Validation Loss', marker='o', ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plotting the Accuracy
sns.lineplot(x=range(1, len(train_acc) + 1), y=train_acc, label='Training Accuracy', marker='o', ax=axes[1])
sns.lineplot(x=range(1, len(val_acc) + 1), y=val_acc, label='Validation Accuracy', marker='o', ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #### On testset

# %%
import torch
from sklearn.metrics import accuracy_score

resnet18.eval()
test_all_labels = []
test_all_predictions = []
test_running_loss = 0.0

criterion = nn.CrossEntropyLoss()

for test_inputs, test_labels in tq.tqdm_notebook(test_dataloader):
    with torch.no_grad():
        test_inputs, test_labels = test_inputs.to(torch.float32).to(device), test_labels.to(device)

        test_outputs = resnet18(test_inputs)
        test_loss = criterion(test_outputs, test_labels)

        _, test_predictions = torch.max(test_outputs, 1)
        test_all_labels.extend(test_labels.cpu().numpy())
        test_all_predictions.extend(test_predictions.cpu().numpy())

        test_running_loss += test_loss.item()

# Calculate accuracy after the loop
test_accuracy = accuracy_score(test_all_labels, test_all_predictions)
average_test_loss = test_running_loss / len(test_dataloader)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# ### Summary

# %%
import pandas as pd
df = pd.DataFrame({'Loss':[train_loss[-1],val_loss[-1],average_test_loss], 
                   'Accuracy':[train_acc[-1]*100, val_acc[-1]*100, test_accuracy*100]})
df = df.set_axis(['Train', 'Validation', 'Test'])
df
# Out:
#                 Loss  Accuracy
# Train       0.783008    96.070
# Validation  0.822406    92.160
# Test        0.860587    88.125

# %%
history = pd.DataFrame({'Train Loss':train_loss,'Validation Loss':val_loss,'Train Accuracy':train_acc,'Validation Accuracy':val_acc})
history.tail(5)
# Out:
#     Train Loss  Validation Loss  Train Accuracy  Validation Accuracy
# 45    0.781274         0.827473          0.9629               0.9170
# 46    0.784871         0.825179          0.9591               0.9184
# 47    0.781155         0.830812          0.9630               0.9112
# 48    0.785400         0.832932          0.9589               0.9100
# 49    0.783008         0.822406          0.9607               0.9216

# %% [markdown]
# ### Save model

# %%
# torch.save(resnet18, "resnet18.pth")
# history.to_csv("resnet18_history.csv")
# df.to_csv("resnet_result.csv")

# %% [markdown]
# ## GoogLeNet

# %% [markdown]
# ### Transfer
# Avialiable to train on CPU or GPU only. MPS is NOT supported.

# %%
import warnings
import pickle
warnings.filterwarnings("ignore")

Dataset = pickle.load(open('Data variable/Dataset.pkl', 'rb'))
train_dataloader = pickle.load(open('Data variable/train_dataloader.pkl', 'rb'))
test_dataloader = pickle.load(open('Data variable/test_dataloader.pkl', 'rb'))
val_dataloader = pickle.load(open('Data variable/val_dataloader.pkl', 'rb'))

# %%
class GoogLeNet_backbone(nn.Module):
    def __init__(self):
        super(GoogLeNet_backbone, self).__init__()
        self.numclass =  4
        self.googlenet = models.googlenet()
        self.googlenet.fc = nn.Identity()
        self.classification_head = nn.Sequential(
                                                    nn.Linear(1024, 512),  # Linear layer
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(512, 256),
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(256, self.numclass),
                                                    nn.Softmax(dim=1),
                                                )
        
    def forward(self, x):
        if self.training:
            x = self.googlenet(x)
            x = self.classification_head(x.logits)
        else:
            x = self.googlenet(x)
            x = self.classification_head(x)
        return x

# %%
googlenet =  GoogLeNet_backbone().to(torch.float32).to(torch.device('cpu'))

# %% [markdown]
# ### Training

# %%
train_loss, train_acc, val_loss, val_acc = train(googlenet,train_dataloader,val_dataloader,device=torch.device('cpu'))
# Out:
# Epoch num:   0%|          | 0/50 [00:00<?, ?it/s]
# -------------------------------------------------------------------
# Epoch 1/50
# Training Loss   : 1.162  |  Training Accuracy   : 0.561
# Validation Loss : 1.386  |  Validation Accuracy : 0.335
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 2/50
# Training Loss   : 1.095  |  Training Accuracy   : 0.634
# Validation Loss : 1.291  |  Validation Accuracy : 0.437
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 3/50
# Training Loss   : 1.081  |  Training Accuracy   : 0.655
# Validation Loss : 1.251  |  Validation Accuracy : 0.479
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 4/50
# Training Loss   : 1.052  |  Training Accuracy   : 0.683
# Validation Loss : 1.210  |  Validation Accuracy : 0.524
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 5/50
# Training Loss   : 1.068  |  Training Accuracy   : 0.672
# Validation Loss : 1.207  |  Validation Accuracy : 0.528
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 6/50
# Training Loss   : 1.039  |  Training Accuracy   : 0.701
# Validation Loss : 1.094  |  Validation Accuracy : 0.643
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 7/50
# Training Loss   : 1.003  |  Training Accuracy   : 0.736
# Validation Loss : 1.027  |  Validation Accuracy : 0.711
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 8/50
# Training Loss   : 0.987  |  Training Accuracy   : 0.754
# Validation Loss : 1.021  |  Validation Accuracy : 0.720
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 9/50
# Training Loss   : 0.982  |  Training Accuracy   : 0.760
# Validation Loss : 1.052  |  Validation Accuracy : 0.687
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 34/50
# Training Loss   : 0.941  |  Training Accuracy   : 0.803
# Validation Loss : 0.995  |  Validation Accuracy : 0.747
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 35/50
# Training Loss   : 0.946  |  Training Accuracy   : 0.797
# Validation Loss : 1.004  |  Validation Accuracy : 0.738
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 36/50
# Training Loss   : 0.933  |  Training Accuracy   : 0.809
# Validation Loss : 0.995  |  Validation Accuracy : 0.746
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 37/50
# Training Loss   : 0.940  |  Training Accuracy   : 0.802
# Validation Loss : 0.990  |  Validation Accuracy : 0.754
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 38/50
# Training Loss   : 0.943  |  Training Accuracy   : 0.801
# Validation Loss : 0.988  |  Validation Accuracy : 0.754
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 39/50
# Training Loss   : 0.937  |  Training Accuracy   : 0.806
# Validation Loss : 0.995  |  Validation Accuracy : 0.749
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 40/50
# Training Loss   : 0.941  |  Training Accuracy   : 0.803
# Validation Loss : 1.001  |  Validation Accuracy : 0.742
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 41/50
# Training Loss   : 0.939  |  Training Accuracy   : 0.805
# Validation Loss : 0.992  |  Validation Accuracy : 0.750
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 42/50
# Training Loss   : 0.943  |  Training Accuracy   : 0.800
# Validation Loss : 1.002  |  Validation Accuracy : 0.741
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 43/50
# Training Loss   : 0.944  |  Training Accuracy   : 0.797
# Validation Loss : 0.990  |  Validation Accuracy : 0.753
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 44/50
# Training Loss   : 0.941  |  Training Accuracy   : 0.801
# Validation Loss : 0.984  |  Validation Accuracy : 0.759
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 45/50
# Training Loss   : 0.943  |  Training Accuracy   : 0.800
# Validation Loss : 0.998  |  Validation Accuracy : 0.746
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 46/50
# Training Loss   : 0.938  |  Training Accuracy   : 0.803
# Validation Loss : 0.991  |  Validation Accuracy : 0.750
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 47/50
# Training Loss   : 0.942  |  Training Accuracy   : 0.801
# Validation Loss : 0.995  |  Validation Accuracy : 0.748
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 48/50
# Training Loss   : 0.943  |  Training Accuracy   : 0.799
# Validation Loss : 0.999  |  Validation Accuracy : 0.745
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 49/50
# Training Loss   : 0.943  |  Training Accuracy   : 0.799
# Validation Loss : 0.995  |  Validation Accuracy : 0.748
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 50/50
# Training Loss   : 0.935  |  Training Accuracy   : 0.807
# Validation Loss : 0.996  |  Validation Accuracy : 0.748
# -------------------------------------------------------------------

# %%
import pandas as pd
history = pd.DataFrame({'Train Loss':train_loss,'Validation Loss':val_loss,'Train Accuracy':train_acc,'Validation Accuracy':val_acc})
history.tail(5)
# Out:
#     Train Loss  Validation Loss  Train Accuracy  Validation Accuracy
# 45    0.938049         0.990865          0.8035               0.7499
# 46    0.942452         0.994766          0.8009               0.7483
# 47    0.943136         0.999276          0.7993               0.7446
# 48    0.942938         0.995154          0.7991               0.7475
# 49    0.935399         0.995542          0.8066               0.7476

# %%
import torch
from sklearn.metrics import accuracy_score

googlenet.eval()
test_all_labels = []
test_all_predictions = []
test_running_loss = 0.0

criterion = nn.CrossEntropyLoss()

for test_inputs, test_labels in tq.tqdm_notebook(test_dataloader):
    with torch.no_grad():
        test_inputs, test_labels = test_inputs.to(torch.float32).to("cpu"), test_labels.to("cpu")

        test_outputs = googlenet(test_inputs)
        test_loss = criterion(test_outputs, test_labels)

        _, test_predictions = torch.max(test_outputs, 1)
        test_all_labels.extend(test_labels.cpu().numpy())
        test_all_predictions.extend(test_predictions.cpu().numpy())

        test_running_loss += test_loss.item()

# Calculate accuracy after the loop
test_accuracy = accuracy_score(test_all_labels, test_all_predictions)
average_test_loss = test_running_loss / len(test_dataloader)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.DataFrame({'Loss':[train_loss[-1],val_loss[-1],average_test_loss], 
                   'Accuracy':[train_acc[-1]*100, val_acc[-1]*100, test_accuracy*100]})
df = df.set_axis(['Train', 'Validation', 'Test'])
df
# Out:
#                 Loss   Accuracy
# Train       0.935399  80.660000
# Validation  0.995542  74.760000
# Test        1.087858  64.895833

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the seaborn style
sns.set(style="whitegrid")

# Create two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the Loss
sns.lineplot(x=range(1, len(train_loss) + 1), y=train_loss, label='Training Loss', marker='o', ax=axes[0])
sns.lineplot(x=range(1, len(val_loss) + 1), y=val_loss, label='Validation Loss', marker='o', ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plotting the Accuracy
sns.lineplot(x=range(1, len(train_acc) + 1), y=train_acc, label='Training Accuracy', marker='o', ax=axes[1])
sns.lineplot(x=range(1, len(val_acc) + 1), y=val_acc, label='Validation Accuracy', marker='o', ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
sum(p.numel() for p in googlenet.parameters())
# Out:
# 12637044

# %% [markdown]
# ### save model

# %%
# torch.save(googlenet, "googlenet.pth")
# history.to_csv("googlenet_history.csv")
# df.to_csv("googlenet_result.csv")

# %% [markdown]
# ## SwinTransformer

# %% [markdown]
# ### Transfer

# %%
import collections
import torch.nn as nn
import torchvision.models as models

class Swintransformer_backbone(nn.Module):
    def __init__(self, num_classes=4):
        super(Swintransformer_backbone, self).__init__()
        self.num_classes = num_classes
        self.swintransformer = models.swin_t()
        self.swintransformer_removelast = nn.Sequential(*list(self.swintransformer.children())[:-1])
        self.classification_head = nn.Sequential(
                                                    nn.Linear(768, 512),  # Linear layer
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(512, 256),
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(256, self.num_classes),
                                                    nn.Softmax(dim=1),
                                                )
        self.swintransformer_backbone = nn.Sequential(
                                                        collections.OrderedDict(
                                                            [
                                                                ("swintransformer", self.swintransformer_removelast),
                                                                ("Head", self.classification_head),
                                                            ]
                                                        )
                                                    )

    def forward(self, x):
        return self.swintransformer_backbone(x)

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
swintransformer = Swintransformer_backbone().to(torch.float32).to(device)

# %%
sum(p.numel() for p in swintransformer.parameters())
# Out:
# 28814438

# %% [markdown]
# ### Training

# %%
train_loss, train_acc, val_loss, val_acc = train(swintransformer,train_dataloader,val_dataloader)

# %% [markdown]
# ## DenseNet

# %% [markdown]
# ### transfer

# %%
import pickle

Dataset = pickle.load(open('Data variable/Dataset.pkl', 'rb'))
train_dataloader = pickle.load(open('Data variable/train_dataloader.pkl', 'rb'))
test_dataloader = pickle.load(open('Data variable/test_dataloader.pkl', 'rb'))
val_dataloader = pickle.load(open('Data variable/val_dataloader.pkl', 'rb'))

# %%
import collections
class DenseNet121_backbone(nn.Module):
    def __init__(self):
        super(DenseNet121_backbone, self).__init__()
        self.numclass =  4
        self.DenseNet121 = models.densenet121()
        self.DenseNet121.classifier = nn.Identity()
        self.classification_head = nn.Sequential(
                                                    nn.Linear(1024, 512),  # Linear layer
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(512, 256),
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(256, self.numclass),
                                                    nn.Softmax(dim=1),
                                                )
        
        self.DenseNet121_backbone = nn.Sequential(
                                                    collections.OrderedDict(
                                                        [
                                                            ("DenseNet121", self.DenseNet121),
                                                            ("Head", self.classification_head),
                                                        ]
                                                    )
                                                )
        
    def forward(self, x):
        return self.DenseNet121_backbone(x)

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
densenet121 =  DenseNet121_backbone().to(torch.float32).to(device)

# %% [markdown]
# ### training

# %%
train_loss, train_acc, val_loss, val_acc = train(densenet121,train_dataloader,val_dataloader)
# Out:
# Epoch num:   0%|          | 0/50 [00:00<?, ?it/s]
# -------------------------------------------------------------------
# Epoch 1/50
# Training Loss   : 1.119  |  Training Accuracy   : 0.606
# Validation Loss : 1.389  |  Validation Accuracy : 0.340
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 2/50
# Training Loss   : 1.063  |  Training Accuracy   : 0.670
# Validation Loss : 1.266  |  Validation Accuracy : 0.463
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 3/50
# Training Loss   : 1.044  |  Training Accuracy   : 0.692
# Validation Loss : 1.284  |  Validation Accuracy : 0.447
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 4/50
# Training Loss   : 1.041  |  Training Accuracy   : 0.696
# Validation Loss : 1.250  |  Validation Accuracy : 0.485
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 5/50
# Training Loss   : 1.000  |  Training Accuracy   : 0.739
# Validation Loss : 1.207  |  Validation Accuracy : 0.529
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 6/50
# Training Loss   : 0.950  |  Training Accuracy   : 0.789
# Validation Loss : 1.003  |  Validation Accuracy : 0.733
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 7/50
# Training Loss   : 0.922  |  Training Accuracy   : 0.820
# Validation Loss : 0.969  |  Validation Accuracy : 0.770
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 8/50
# Training Loss   : 0.898  |  Training Accuracy   : 0.845
# Validation Loss : 0.970  |  Validation Accuracy : 0.769
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 9/50
# Training Loss   : 0.884  |  Training Accuracy   : 0.858
# Validation Loss : 0.948  |  Validation Accuracy : 0.795
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 10/50
# Training Loss   : 0.871  |  Training Accuracy   : 0.873
# Validation Loss : 0.943  |  Validation Accuracy : 0.799
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 11/50
# Training Loss   : 0.860  |  Training Accuracy   : 0.883
# Validation Loss : 0.942  |  Validation Accuracy : 0.801
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 12/50
# Training Loss   : 0.856  |  Training Accuracy   : 0.888
# Validation Loss : 0.937  |  Validation Accuracy : 0.803
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 13/50
# Training Loss   : 0.851  |  Training Accuracy   : 0.893
# Validation Loss : 0.932  |  Validation Accuracy : 0.806
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 14/50
# Training Loss   : 0.849  |  Training Accuracy   : 0.895
# Validation Loss : 0.930  |  Validation Accuracy : 0.811
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 15/50
# Training Loss   : 0.847  |  Training Accuracy   : 0.898
# Validation Loss : 0.922  |  Validation Accuracy : 0.820
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 40/50
# Training Loss   : 0.845  |  Training Accuracy   : 0.899
# Validation Loss : 0.930  |  Validation Accuracy : 0.812
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 41/50
# Training Loss   : 0.847  |  Training Accuracy   : 0.896
# Validation Loss : 0.916  |  Validation Accuracy : 0.825
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 42/50
# Training Loss   : 0.848  |  Training Accuracy   : 0.896
# Validation Loss : 0.925  |  Validation Accuracy : 0.815
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 43/50
# Training Loss   : 0.847  |  Training Accuracy   : 0.896
# Validation Loss : 0.925  |  Validation Accuracy : 0.817
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 44/50
# Training Loss   : 0.845  |  Training Accuracy   : 0.900
# Validation Loss : 0.921  |  Validation Accuracy : 0.820
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 45/50
# Training Loss   : 0.845  |  Training Accuracy   : 0.898
# Validation Loss : 0.928  |  Validation Accuracy : 0.812
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 46/50
# Training Loss   : 0.845  |  Training Accuracy   : 0.899
# Validation Loss : 0.923  |  Validation Accuracy : 0.818
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 47/50
# Training Loss   : 0.843  |  Training Accuracy   : 0.901
# Validation Loss : 0.925  |  Validation Accuracy : 0.814
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 48/50
# Training Loss   : 0.852  |  Training Accuracy   : 0.891
# Validation Loss : 0.924  |  Validation Accuracy : 0.818
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 49/50
# Training Loss   : 0.851  |  Training Accuracy   : 0.893
# Validation Loss : 0.932  |  Validation Accuracy : 0.808
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 50/50
# Training Loss   : 0.847  |  Training Accuracy   : 0.896
# Validation Loss : 0.928  |  Validation Accuracy : 0.811
# -------------------------------------------------------------------

# %%
import pandas as pd
history = pd.DataFrame({'Train Loss':train_loss,'Validation Loss':val_loss,'Train Accuracy':train_acc,'Validation Accuracy':val_acc})
history.tail(5)
# Out:
#     Train Loss  Validation Loss  Train Accuracy  Validation Accuracy
# 45    0.844839         0.922749          0.8987               0.8179
# 46    0.843020         0.924519          0.9013               0.8140
# 47    0.851902         0.924224          0.8911               0.8182
# 48    0.850569         0.932125          0.8935               0.8079
# 49    0.846985         0.928024          0.8960               0.8114

# %%
import torch
from sklearn.metrics import accuracy_score

densenet121.eval()
test_all_labels = []
test_all_predictions = []
test_running_loss = 0.0

criterion = nn.CrossEntropyLoss()

for test_inputs, test_labels in tq.tqdm_notebook(test_dataloader):
    with torch.no_grad():
        test_inputs, test_labels = test_inputs.to(torch.float32).to(device), test_labels.to(device)

        test_outputs = densenet121(test_inputs)
        test_loss = criterion(test_outputs, test_labels)

        _, test_predictions = torch.max(test_outputs, 1)
        test_all_labels.extend(test_labels.cpu().numpy())
        test_all_predictions.extend(test_predictions.cpu().numpy())

        test_running_loss += test_loss.item()

# Calculate accuracy after the loop
test_accuracy = accuracy_score(test_all_labels, test_all_predictions)
average_test_loss = test_running_loss / len(test_dataloader)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.DataFrame({'Loss':[train_loss[-1],val_loss[-1],average_test_loss], 
                   'Accuracy':[train_acc[-1]*100, val_acc[-1]*100, test_accuracy*100]})
df = df.set_axis(['Train', 'Validation', 'Test'])
df
# Out:
#                 Loss   Accuracy
# Train       0.846985  89.600000
# Validation  0.928024  81.140000
# Test        0.962649  78.020833

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the seaborn style
sns.set(style="whitegrid")

# Create two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the Loss
sns.lineplot(x=range(1, len(train_loss) + 1), y=train_loss, label='Training Loss', marker='o', ax=axes[0])
sns.lineplot(x=range(1, len(val_loss) + 1), y=val_loss, label='Validation Loss', marker='o', ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plotting the Accuracy
sns.lineplot(x=range(1, len(train_acc) + 1), y=train_acc, label='Training Accuracy', marker='o', ax=axes[1])
sns.lineplot(x=range(1, len(val_acc) + 1), y=val_acc, label='Validation Accuracy', marker='o', ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
sum(p.numel() for p in densenet121.parameters())
# Out:
# 7611012

# %% [markdown]
# ### save model

# %%
# torch.save(densenet121, "densenet121.pth")
# history.to_csv("densenet121_history.csv")
# df.to_csv("densenet121_result.csv")

# %% [markdown]
# ## EfficientNet

# %% [markdown]
# ### transfer

# %%
import pickle

Dataset = pickle.load(open('Data variable/Dataset.pkl', 'rb'))
train_dataloader = pickle.load(open('Data variable/train_dataloader.pkl', 'rb'))
test_dataloader = pickle.load(open('Data variable/test_dataloader.pkl', 'rb'))
val_dataloader = pickle.load(open('Data variable/val_dataloader.pkl', 'rb'))

# %%
import collections
class EfficientNet_backbone(nn.Module):
    def __init__(self):
        super(EfficientNet_backbone, self).__init__()
        self.numclass =  4
        self.EfficientNet = models.efficientnet_b2()
        self.EfficientNet.classifier = nn.Identity()
        self.classification_head = nn.Sequential(
                                                    nn.Dropout(0.3, inplace=True),
                                                    nn.Linear(1408, 512),  # Linear layer
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(512, 256),
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(256, self.numclass),
                                                    nn.Softmax(dim=1),
                                                )
        
        self.EfficientNet_backbone = nn.Sequential(
                                                    collections.OrderedDict(
                                                        [
                                                            ("EfficientNet", self.EfficientNet),
                                                            ("Head", self.classification_head),
                                                        ]
                                                    )
                                                )
        
    def forward(self, x):
        return self.EfficientNet_backbone(x)

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
efficientnet =  EfficientNet_backbone().to(torch.float32).to(device)

# %% [markdown]
# ### training

# %%
train_loss, train_acc, val_loss, val_acc = train(efficientnet,train_dataloader,val_dataloader)
# Out:
# Epoch num:   0%|          | 0/50 [00:00<?, ?it/s]
# -------------------------------------------------------------------
# Epoch 1/50
# Training Loss   : 1.219  |  Training Accuracy   : 0.472
# Validation Loss : 1.291  |  Validation Accuracy : 0.373
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 2/50
# Training Loss   : 1.126  |  Training Accuracy   : 0.598
# Validation Loss : 1.214  |  Validation Accuracy : 0.513
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 3/50
# Training Loss   : 1.182  |  Training Accuracy   : 0.546
# Validation Loss : 1.235  |  Validation Accuracy : 0.492
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 4/50
# Training Loss   : 1.227  |  Training Accuracy   : 0.485
# Validation Loss : 1.281  |  Validation Accuracy : 0.435
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 5/50
# Training Loss   : 1.283  |  Training Accuracy   : 0.397
# Validation Loss : 1.322  |  Validation Accuracy : 0.359
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 6/50
# Training Loss   : 1.191  |  Training Accuracy   : 0.488
# Validation Loss : 1.224  |  Validation Accuracy : 0.453
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 31/50
# Training Loss   : 1.156  |  Training Accuracy   : 0.571
# Validation Loss : 1.184  |  Validation Accuracy : 0.554
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 32/50
# Training Loss   : 1.154  |  Training Accuracy   : 0.571
# Validation Loss : 1.185  |  Validation Accuracy : 0.555
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 33/50
# Training Loss   : 1.159  |  Training Accuracy   : 0.562
# Validation Loss : 1.184  |  Validation Accuracy : 0.554
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 34/50
# Training Loss   : 1.155  |  Training Accuracy   : 0.567
# Validation Loss : 1.185  |  Validation Accuracy : 0.553
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 35/50
# Training Loss   : 1.159  |  Training Accuracy   : 0.563
# Validation Loss : 1.183  |  Validation Accuracy : 0.556
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 36/50
# Training Loss   : 1.160  |  Training Accuracy   : 0.566
# Validation Loss : 1.182  |  Validation Accuracy : 0.556
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 37/50
# Training Loss   : 1.154  |  Training Accuracy   : 0.575
# Validation Loss : 1.186  |  Validation Accuracy : 0.554
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 38/50
# Training Loss   : 1.153  |  Training Accuracy   : 0.569
# Validation Loss : 1.188  |  Validation Accuracy : 0.552
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 39/50
# Training Loss   : 1.152  |  Training Accuracy   : 0.579
# Validation Loss : 1.187  |  Validation Accuracy : 0.547
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 40/50
# Training Loss   : 1.159  |  Training Accuracy   : 0.566
# Validation Loss : 1.181  |  Validation Accuracy : 0.556
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 41/50
# Training Loss   : 1.157  |  Training Accuracy   : 0.568
# Validation Loss : 1.183  |  Validation Accuracy : 0.551
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 42/50
# Training Loss   : 1.157  |  Training Accuracy   : 0.564
# Validation Loss : 1.181  |  Validation Accuracy : 0.554
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 43/50
# Training Loss   : 1.153  |  Training Accuracy   : 0.566
# Validation Loss : 1.187  |  Validation Accuracy : 0.548
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 44/50
# Training Loss   : 1.155  |  Training Accuracy   : 0.566
# Validation Loss : 1.185  |  Validation Accuracy : 0.552
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 45/50
# Training Loss   : 1.162  |  Training Accuracy   : 0.555
# Validation Loss : 1.184  |  Validation Accuracy : 0.552
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 46/50
# Training Loss   : 1.158  |  Training Accuracy   : 0.567
# Validation Loss : 1.180  |  Validation Accuracy : 0.558
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 47/50
# Training Loss   : 1.157  |  Training Accuracy   : 0.567
# Validation Loss : 1.185  |  Validation Accuracy : 0.555
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 48/50
# Training Loss   : 1.160  |  Training Accuracy   : 0.565
# Validation Loss : 1.180  |  Validation Accuracy : 0.559
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 49/50
# Training Loss   : 1.160  |  Training Accuracy   : 0.562
# Validation Loss : 1.178  |  Validation Accuracy : 0.560
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 50/50
# Training Loss   : 1.153  |  Training Accuracy   : 0.574
# Validation Loss : 1.188  |  Validation Accuracy : 0.549
# -------------------------------------------------------------------

# %%
import pandas as pd
history = pd.DataFrame({'Train Loss':train_loss,'Validation Loss':val_loss,'Train Accuracy':train_acc,'Validation Accuracy':val_acc})
history.tail(5)
# Out:
#     Train Loss  Validation Loss  Train Accuracy  Validation Accuracy
# 45    1.158433         1.180093          0.5674               0.5584
# 46    1.157187         1.185215          0.5673               0.5554
# 47    1.160026         1.180122          0.5646               0.5587
# 48    1.160422         1.178100          0.5619               0.5596
# 49    1.153126         1.188192          0.5739               0.5490

# %%
import torch
from sklearn.metrics import accuracy_score

efficientnet.eval()
test_all_labels = []
test_all_predictions = []
test_running_loss = 0.0

criterion = nn.CrossEntropyLoss()

for test_inputs, test_labels in tq.tqdm_notebook(test_dataloader):
    with torch.no_grad():
        test_inputs, test_labels = test_inputs.to(torch.float32).to(device), test_labels.to(device)

        test_outputs = efficientnet(test_inputs)
        test_loss = criterion(test_outputs, test_labels)

        _, test_predictions = torch.max(test_outputs, 1)
        test_all_labels.extend(test_labels.cpu().numpy())
        test_all_predictions.extend(test_predictions.cpu().numpy())

        test_running_loss += test_loss.item()

# Calculate accuracy after the loop
test_accuracy = accuracy_score(test_all_labels, test_all_predictions)
average_test_loss = test_running_loss / len(test_dataloader)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.DataFrame({'Loss':[train_loss[-1],val_loss[-1],average_test_loss], 
                   'Accuracy':[train_acc[-1]*100, val_acc[-1]*100, test_accuracy*100]})
df = df.set_axis(['Train', 'Validation', 'Test'])
df
# Out:
#                 Loss  Accuracy
# Train       1.153126   57.3900
# Validation  1.188192   54.9000
# Test        1.253054   45.9375

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the seaborn style
sns.set(style="whitegrid")

# Create two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the Loss
sns.lineplot(x=range(1, len(train_loss) + 1), y=train_loss, label='Training Loss', marker='o', ax=axes[0])
sns.lineplot(x=range(1, len(val_loss) + 1), y=val_loss, label='Validation Loss', marker='o', ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plotting the Accuracy
sns.lineplot(x=range(1, len(train_acc) + 1), y=train_acc, label='Training Accuracy', marker='o', ax=axes[1])
sns.lineplot(x=range(1, len(val_acc) + 1), y=val_acc, label='Validation Accuracy', marker='o', ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
sum(p.numel() for p in efficientnet.parameters())
# Out:
# 8554758

# %% [markdown]
# ### save model

# %%
# torch.save(efficientnet, "efficientnet_b2.pth")
# history.to_csv("efficientnet_b2_history.csv")
# df.to_csv("efficientnet_b2_result.csv")

# %% [markdown]
# ## RegNet

# %% [markdown]
# ### transfer

# %%
import pickle

Dataset = pickle.load(open('Data variable/Dataset.pkl', 'rb'))
train_dataloader = pickle.load(open('Data variable/train_dataloader.pkl', 'rb'))
test_dataloader = pickle.load(open('Data variable/test_dataloader.pkl', 'rb'))
val_dataloader = pickle.load(open('Data variable/val_dataloader.pkl', 'rb'))

# %%
import collections
class RegNet_backbone(nn.Module):
    def __init__(self):
        super(RegNet_backbone, self).__init__()
        self.numclass =  4
        self.regnet_y_800mf = models.regnet_y_800mf()
        self.regnet_y_800mf.fc = nn.Identity()
        self.classification_head = nn.Sequential(
                                                    nn.Linear(784, 512),  # Linear layer
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(512, 256),
                                                    nn.ReLU(inplace=True),
                                                    nn.Linear(256, self.numclass),
                                                    nn.Softmax(dim=1),
                                                )
        
        self.RegNet_backbone = nn.Sequential(
                                                    collections.OrderedDict(
                                                        [
                                                            ("RegNet", self.regnet_y_800mf),
                                                            ("Head", self.classification_head),
                                                        ]
                                                    )
                                                )
        
    def forward(self, x):
        return self.RegNet_backbone(x)

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
regnet = RegNet_backbone().to(torch.float32).to(device)

# %% [markdown]
# ### training

# %%
train_loss, train_acc, val_loss, val_acc = train(regnet,train_dataloader,val_dataloader)
# Out:
# Epoch num:   0%|          | 0/50 [00:00<?, ?it/s]
# -------------------------------------------------------------------
# Epoch 1/50
# Training Loss   : 1.115  |  Training Accuracy   : 0.611
# Validation Loss : 1.322  |  Validation Accuracy : 0.402
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 2/50
# Training Loss   : 1.034  |  Training Accuracy   : 0.705
# Validation Loss : 1.206  |  Validation Accuracy : 0.530
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 3/50
# Training Loss   : 0.974  |  Training Accuracy   : 0.766
# Validation Loss : 1.106  |  Validation Accuracy : 0.632
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 4/50
# Training Loss   : 0.957  |  Training Accuracy   : 0.782
# Validation Loss : 1.158  |  Validation Accuracy : 0.581
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 5/50
# Training Loss   : 0.927  |  Training Accuracy   : 0.815
# Validation Loss : 1.065  |  Validation Accuracy : 0.674
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 6/50
# Training Loss   : 0.871  |  Training Accuracy   : 0.871
# Validation Loss : 0.966  |  Validation Accuracy : 0.774
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 7/50
# Training Loss   : 0.838  |  Training Accuracy   : 0.905
# Validation Loss : 0.940  |  Validation Accuracy : 0.801
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 8/50
# Training Loss   : 0.829  |  Training Accuracy   : 0.914
# Validation Loss : 0.924  |  Validation Accuracy : 0.816
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 9/50
# Training Loss   : 0.818  |  Training Accuracy   : 0.925
# Validation Loss : 0.940  |  Validation Accuracy : 0.801
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 10/50
# Training Loss   : 0.810  |  Training Accuracy   : 0.932
# Validation Loss : 0.918  |  Validation Accuracy : 0.823
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 11/50
# Training Loss   : 0.797  |  Training Accuracy   : 0.947
# Validation Loss : 0.920  |  Validation Accuracy : 0.820
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 12/50
# Training Loss   : 0.793  |  Training Accuracy   : 0.952
# Validation Loss : 0.916  |  Validation Accuracy : 0.823
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 13/50
# Training Loss   : 0.791  |  Training Accuracy   : 0.953
# Validation Loss : 0.916  |  Validation Accuracy : 0.824
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 14/50
# Training Loss   : 0.789  |  Training Accuracy   : 0.956
# Validation Loss : 0.914  |  Validation Accuracy : 0.827
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 15/50
# Training Loss   : 0.787  |  Training Accuracy   : 0.958
# Validation Loss : 0.916  |  Validation Accuracy : 0.824
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 16/50
# Training Loss   : 0.787  |  Training Accuracy   : 0.957
# Validation Loss : 0.918  |  Validation Accuracy : 0.820
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 17/50
# Training Loss   : 0.785  |  Training Accuracy   : 0.960
# Validation Loss : 0.917  |  Validation Accuracy : 0.820
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 18/50
# Training Loss   : 0.786  |  Training Accuracy   : 0.958
# Validation Loss : 0.914  |  Validation Accuracy : 0.827
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 19/50
# Training Loss   : 0.787  |  Training Accuracy   : 0.958
# Validation Loss : 0.919  |  Validation Accuracy : 0.819
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 20/50
# Training Loss   : 0.786  |  Training Accuracy   : 0.958
# Validation Loss : 0.919  |  Validation Accuracy : 0.821
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 21/50
# Training Loss   : 0.788  |  Training Accuracy   : 0.955
# Validation Loss : 0.914  |  Validation Accuracy : 0.826
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 22/50
# Training Loss   : 0.783  |  Training Accuracy   : 0.961
# Validation Loss : 0.922  |  Validation Accuracy : 0.818
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 47/50
# Training Loss   : 0.787  |  Training Accuracy   : 0.958
# Validation Loss : 0.913  |  Validation Accuracy : 0.828
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 48/50
# Training Loss   : 0.785  |  Training Accuracy   : 0.960
# Validation Loss : 0.911  |  Validation Accuracy : 0.832
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 49/50
# Training Loss   : 0.786  |  Training Accuracy   : 0.959
# Validation Loss : 0.909  |  Validation Accuracy : 0.832
# -------------------------------------------------------------------
#
# -------------------------------------------------------------------
# Epoch 50/50
# Training Loss   : 0.790  |  Training Accuracy   : 0.954
# Validation Loss : 0.909  |  Validation Accuracy : 0.832
# -------------------------------------------------------------------

# %%
import pandas as pd
history = pd.DataFrame({'Train Loss':train_loss,'Validation Loss':val_loss,'Train Accuracy':train_acc,'Validation Accuracy':val_acc})
history.tail(5)
# Out:
#     Train Loss  Validation Loss  Train Accuracy  Validation Accuracy
# 45    0.785278         0.918002          0.9587               0.8217
# 46    0.787226         0.913144          0.9576               0.8279
# 47    0.784590         0.911309          0.9599               0.8319
# 48    0.785834         0.908926          0.9585               0.8315
# 49    0.789950         0.909108          0.9543               0.8322

# %%
import torch
from sklearn.metrics import accuracy_score

regnet.eval()
test_all_labels = []
test_all_predictions = []
test_running_loss = 0.0

criterion = nn.CrossEntropyLoss()

for test_inputs, test_labels in tq.tqdm_notebook(test_dataloader):
    with torch.no_grad():
        test_inputs, test_labels = test_inputs.to(torch.float32).to(device), test_labels.to(device)

        test_outputs = regnet(test_inputs)
        test_loss = criterion(test_outputs, test_labels)

        _, test_predictions = torch.max(test_outputs, 1)
        test_all_labels.extend(test_labels.cpu().numpy())
        test_all_predictions.extend(test_predictions.cpu().numpy())

        test_running_loss += test_loss.item()

# Calculate accuracy after the loop
test_accuracy = accuracy_score(test_all_labels, test_all_predictions)
average_test_loss = test_running_loss / len(test_dataloader)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.DataFrame({'Loss':[train_loss[-1],val_loss[-1],average_test_loss], 
                   'Accuracy':[train_acc[-1]*100, val_acc[-1]*100, test_accuracy*100]})
df = df.set_axis(['Train', 'Validation', 'Test'])
df
# Out:
#                 Loss   Accuracy
# Train       0.789950  95.430000
# Validation  0.909108  83.220000
# Test        0.901037  83.958333

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the seaborn style
sns.set(style="whitegrid")

# Create two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plotting the Loss
sns.lineplot(x=range(1, len(train_loss) + 1), y=train_loss, label='Training Loss', marker='o', ax=axes[0])
sns.lineplot(x=range(1, len(val_loss) + 1), y=val_loss, label='Validation Loss', marker='o', ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plotting the Accuracy
sns.lineplot(x=range(1, len(train_acc) + 1), y=train_acc, label='Training Accuracy', marker='o', ax=axes[1])
sns.lineplot(x=range(1, len(val_acc) + 1), y=val_acc, label='Validation Accuracy', marker='o', ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
sum(p.numel() for p in regnet.parameters())
# Out:
# 6181788

# %% [markdown]
# ### save model

# %%
torch.save(regnet, "regnet_y_800mf.pth")
history.to_csv("regnet_y_800mf_history.csv")
df.to_csv("regnet_y_800mf_result.csv")
